# %%
import tensorflow as tf
old_v = tf.logging.get_verbosity()
tf.logging.set_verbosity(tf.logging.ERROR)

# %% [markdown]
# <h2>Extract MNIST data</h2>
# <p style="font-size:20px">You can change the option of one_hot encoding.

# %%
from tensorflow.examples.tutorials.mnist import input_data
#get mnist data, with one_hot encoding
mnist = input_data.read_data_sets("MNIST_data/",one_hot=True)
#suppress warnings
tf.logging.set_verbosity(old_v)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# <h2>Experiment</h2>

# %% [markdown]
# experiment 1:
# NUM_ITER = 100
# lr = 0.01
# batch_size = 64
# n_hidden_1 = 200
# n_hidden_2 = 100

# %%
# hyperparameters
NUM_ITER = 100
lr = 0.01
batch_size = 64
num_input = 784
n_hidden_1 = 200
n_hidden_2 = 100
num_classes = 10

# define variables, weights and biases
tf.reset_default_graph()
X = tf.placeholder(tf.float32,[None, num_input], name='X')
Y = tf.placeholder(tf.int32,[None, num_classes], name='Y')
weights = {
    'W1': tf.Variable(tf.random_normal([num_input, n_hidden_1]), name='W1'),
    'W2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2]), name='W2'),
    'Wout': tf.Variable(tf.random_normal([n_hidden_2, num_classes]), name='Wout')
}
biases = {
    'b1': tf.Variable(tf.zeros(shape=[n_hidden_1]), name='b1'),
    'b2': tf.Variable(tf.zeros(shape=[n_hidden_2]), name='b2'),
    'bout': tf.Variable(tf.zeros(shape=[num_classes]), name='bout')
}

# define neural nets
def neural_net(x):
    l1_out = tf.add(tf.matmul(x,weights['W1']), biases['b1'])
    l2_out = tf.add(tf.matmul(l1_out,weights['W2']), biases['b2'])
    out = tf.add(tf.matmul(l2_out,weights['Wout']), biases['bout'])
    return out

logits = neural_net(X)

# define loss and optimizer
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=lr)
train_op = optimizer.minimize(loss)

# evaluate
correct_pred = tf.equal(tf.argmax(logits,1), tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# initialize the variables
init = tf.global_variables_initializer()

# execute training
with tf.Session() as sess:
    sess.run(init)

    for i in range(NUM_ITER):
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        sess.run(train_op, feed_dict={X:batch_x, Y:batch_y})
#         if i % 100 ==0:
#             acc = sess.run(accuracy,feed_dict={X:batch_x, Y:batch_y})
#             print("step "+str(i)+", Accuracy= {:.3f}".format(acc))

    print("num_iter:%d, lr:%s, batch_size:%d, n_hidden_1:%d, n_hidden_2:%d, test_acc:%.4f" \
          % (NUM_ITER, lr, batch_size, n_hidden_1, n_hidden_2, 
             sess.run(accuracy, feed_dict={X:mnist.test.images, Y:mnist.test.labels})))
# Out:
# num_iter:100, lr:0.01, batch_size:64, n_hidden_1:200, n_hidden_2:100, test_acc:0.8373

# %%
# hyperparameters
NUM_ITER = 1000
lr = 0.01
batch_size = 64
num_input = 784
n_hidden_1 = 200
n_hidden_2 = 100
num_classes = 10

# define variables, weights and biases
tf.reset_default_graph()
X = tf.placeholder(tf.float32,[None, num_input], name='X')
Y = tf.placeholder(tf.int32,[None, num_classes], name='Y')
weights = {
    'W1': tf.Variable(tf.random_normal([num_input, n_hidden_1]), name='W1'),
    'W2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2]), name='W2'),
    'Wout': tf.Variable(tf.random_normal([n_hidden_2, num_classes]), name='Wout')
}
biases = {
    'b1': tf.Variable(tf.zeros(shape=[n_hidden_1]), name='b1'),
    'b2': tf.Variable(tf.zeros(shape=[n_hidden_2]), name='b2'),
    'bout': tf.Variable(tf.zeros(shape=[num_classes]), name='bout')
}

# define neural nets
def neural_net(x):
    l1_out = tf.add(tf.matmul(x,weights['W1']), biases['b1'])
    l2_out = tf.add(tf.matmul(l1_out,weights['W2']), biases['b2'])
    out = tf.add(tf.matmul(l2_out,weights['Wout']), biases['bout'])
    return out

logits = neural_net(X)

# define loss and optimizer
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=lr)
train_op = optimizer.minimize(loss)

# evaluate
correct_pred = tf.equal(tf.argmax(logits,1), tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# initialize the variables
init = tf.global_variables_initializer()

# execute training
with tf.Session() as sess:
    sess.run(init)

    for i in range(NUM_ITER):
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        sess.run(train_op, feed_dict={X:batch_x, Y:batch_y})
#         if i % 100 ==0:
#             acc = sess.run(accuracy,feed_dict={X:batch_x, Y:batch_y})
#             print("step "+str(i)+", Accuracy= {:.3f}".format(acc))

    print("num_iter:%d, lr:%s, batch_size:%d, n_hidden_1:%d, n_hidden_2:%d, test_acc:%.4f" \
          % (NUM_ITER, lr, batch_size, n_hidden_1, n_hidden_2, 
             sess.run(accuracy, feed_dict={X:mnist.test.images, Y:mnist.test.labels})))
# Out:
# num_iter:1000, lr:0.01, batch_size:64, n_hidden_1:200, n_hidden_2:100, test_acc:0.8561

# %%
# hyperparameters
NUM_ITER = 1000
lr = 0.001
batch_size = 64
num_input = 784
n_hidden_1 = 512
n_hidden_2 = 256
num_classes = 10

# define variables, weights and biases
tf.reset_default_graph()
X = tf.placeholder(tf.float32,[None, num_input], name='X')
Y = tf.placeholder(tf.int32,[None, num_classes], name='Y')
weights = {
    'W1': tf.Variable(tf.random_normal([num_input, n_hidden_1]), name='W1'),
    'W2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2]), name='W2'),
    'Wout': tf.Variable(tf.random_normal([n_hidden_2, num_classes]), name='Wout')
}
biases = {
    'b1': tf.Variable(tf.zeros(shape=[n_hidden_1]), name='b1'),
    'b2': tf.Variable(tf.zeros(shape=[n_hidden_2]), name='b2'),
    'bout': tf.Variable(tf.zeros(shape=[num_classes]), name='bout')
}

# define neural nets
def neural_net(x):
    l1_out = tf.add(tf.matmul(x,weights['W1']), biases['b1'])
    l2_out = tf.add(tf.matmul(l1_out,weights['W2']), biases['b2'])
    out = tf.add(tf.matmul(l2_out,weights['Wout']), biases['bout'])
    return out

logits = neural_net(X)

# define loss and optimizer
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=lr)
train_op = optimizer.minimize(loss)

# evaluate
correct_pred = tf.equal(tf.argmax(logits,1), tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# initialize the variables
init = tf.global_variables_initializer()

# execute training
with tf.Session() as sess:
    sess.run(init)

    for i in range(NUM_ITER):
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        sess.run(train_op, feed_dict={X:batch_x, Y:batch_y})
#         if i % 100 ==0:
#             acc = sess.run(accuracy,feed_dict={X:batch_x, Y:batch_y})
#             print("step "+str(i)+", Accuracy= {:.3f}".format(acc))

    print("num_iter:%d, lr:%s, batch_size:%d, n_hidden_1:%d, n_hidden_2:%d, test_acc:%.4f" \
          % (NUM_ITER, lr, batch_size, n_hidden_1, n_hidden_2, 
             sess.run(accuracy, feed_dict={X:mnist.test.images, Y:mnist.test.labels})))
# Out:
# num_iter:1000, lr:0.001, batch_size:64, n_hidden_1:512, n_hidden_2:256, test_acc:0.8707

# %%
# hyperparameters
NUM_ITER = 100000
lr = 0.0001
batch_size = 256
num_input = 784
n_hidden_1 = 512
n_hidden_2 = 256
num_classes = 10

# define variables, weights and biases
tf.reset_default_graph()
X = tf.placeholder(tf.float32,[None, num_input], name='X')
Y = tf.placeholder(tf.int32,[None, num_classes], name='Y')
weights = {
    'W1': tf.Variable(tf.random_normal([num_input, n_hidden_1]), name='W1'),
    'W2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2]), name='W2'),
    'Wout': tf.Variable(tf.random_normal([n_hidden_2, num_classes]), name='Wout')
}
biases = {
    'b1': tf.Variable(tf.zeros(shape=[n_hidden_1]), name='b1'),
    'b2': tf.Variable(tf.zeros(shape=[n_hidden_2]), name='b2'),
    'bout': tf.Variable(tf.zeros(shape=[num_classes]), name='bout')
}

# define neural nets
def neural_net(x):
    x = tf.layers.batch_normalization(x)
    l1_out = tf.nn.relu(tf.add(tf.matmul(x,weights['W1']), biases['b1']))
    l1_drop=tf.layers.dropout(l1_out,rate=0.3)
    l2_out = tf.nn.relu(tf.add(tf.matmul(l1_drop,weights['W2']), biases['b2']))
    l2_drop=tf.layers.dropout(l2_out,rate=0.3)
    out = tf.add(tf.matmul(l2_drop,weights['Wout']), biases['bout'])
    return out

logits = neural_net(X)

# define loss and optimizer
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=lr)
train_op = optimizer.minimize(loss)

# evaluate
correct_pred = tf.equal(tf.argmax(logits,1), tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# initialize the variables
init = tf.global_variables_initializer()

# execute training
with tf.Session() as sess:
    sess.run(init)

    for i in range(NUM_ITER):
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        sess.run(train_op, feed_dict={X:batch_x, Y:batch_y})
        if i % 1000 ==0:
             acc = sess.run(accuracy,feed_dict={X:batch_x, Y:batch_y})
             print("step "+str(i)+", Accuracy= {:.3f}".format(acc))

    print("num_iter:%d, lr:%s, batch_size:%d, n_hidden_1:%d, n_hidden_2:%d, test_acc:%.4f" \
          % (NUM_ITER, lr, batch_size, n_hidden_1, n_hidden_2, 
             sess.run(accuracy, feed_dict={X:mnist.test.images, Y:mnist.test.labels})))
# Out:
# step 0, Accuracy= 0.109
# step 1000, Accuracy= 0.762
# step 2000, Accuracy= 0.801
# step 3000, Accuracy= 0.840
# step 4000, Accuracy= 0.820
# step 5000, Accuracy= 0.863
# step 6000, Accuracy= 0.895
# step 7000, Accuracy= 0.859
# step 8000, Accuracy= 0.836
# step 9000, Accuracy= 0.875
# step 10000, Accuracy= 0.871
# step 11000, Accuracy= 0.879
# step 12000, Accuracy= 0.887
# step 13000, Accuracy= 0.887
# step 14000, Accuracy= 0.902
# step 15000, Accuracy= 0.887
# step 16000, Accuracy= 0.883
# step 17000, Accuracy= 0.883
# step 18000, Accuracy= 0.871
# step 19000, Accuracy= 0.918
# step 20000, Accuracy= 0.906
# step 21000, Accuracy= 0.910
# step 22000, Accuracy= 0.930
# step 23000, Accuracy= 0.895
# step 24000, Accuracy= 0.879
# step 25000, Accuracy= 0.910
# step 26000, Accuracy= 0.891
# step 27000, Accuracy= 0.918
# step 28000, Accuracy= 0.898
# step 29000, Accuracy= 0.895
# step 30000, Accuracy= 0.922
# step 31000, Accuracy= 0.934
# step 32000, Accuracy= 0.957
# ...

# %%
# hyperparameters
NUM_ITER = 20000
lr = 0.0001
batch_size = 256
num_input = 784
n_hidden_1 = 512
n_hidden_2 = 256
num_classes = 10

# define variables, weights and biases
tf.reset_default_graph()
X = tf.placeholder(tf.float32,[None, num_input], name='X')
Y = tf.placeholder(tf.int32,[None, num_classes], name='Y')
weights = {
    'W1': tf.Variable(tf.random_normal([num_input, n_hidden_1]), name='W1'),
    'W2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2]), name='W2'),
    'Wout': tf.Variable(tf.random_normal([n_hidden_2, num_classes]), name='Wout')
}
biases = {
    'b1': tf.Variable(tf.zeros(shape=[n_hidden_1]), name='b1'),
    'b2': tf.Variable(tf.zeros(shape=[n_hidden_2]), name='b2'),
    'bout': tf.Variable(tf.zeros(shape=[num_classes]), name='bout')
}

# define neural nets
def neural_net(x):
    x = tf.layers.batch_normalization(x)
    l1_out = tf.nn.relu(tf.add(tf.matmul(x,weights['W1']), biases['b1']))
    l1_drop=tf.layers.dropout(l1_out,rate=0.3)
    l2_out = tf.nn.relu(tf.add(tf.matmul(l1_drop,weights['W2']), biases['b2']))
    l2_drop=tf.layers.dropout(l2_out,rate=0.3)
    out = tf.add(tf.matmul(l2_drop,weights['Wout']), biases['bout'])
    return out

logits = neural_net(X)

# define loss and optimizer
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=Y)) \
       + 0.1*(tf.reduce_sum(tf.square(biases['b1'])) + tf.reduce_sum(tf.square(biases['b2'])))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=lr)
train_op = optimizer.minimize(loss)

# evaluate
correct_pred = tf.equal(tf.argmax(logits,1), tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# initialize the variables
init = tf.global_variables_initializer()

# execute training
with tf.Session() as sess:
    sess.run(init)

    for i in range(NUM_ITER):
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        sess.run(train_op, feed_dict={X:batch_x, Y:batch_y})
        if i % 1000 ==0:
             acc = sess.run(accuracy,feed_dict={X:batch_x, Y:batch_y})
             print("step "+str(i)+", Accuracy= {:.3f}".format(acc))

    print("num_iter:%d, lr:%s, batch_size:%d, n_hidden_1:%d, n_hidden_2:%d, test_acc:%.4f" \
          % (NUM_ITER, lr, batch_size, n_hidden_1, n_hidden_2, 
             sess.run(accuracy, feed_dict={X:mnist.test.images, Y:mnist.test.labels})))
# Out:
# step 0, Accuracy= 0.199
# step 1000, Accuracy= 0.805
# step 2000, Accuracy= 0.805
# step 3000, Accuracy= 0.836
# step 4000, Accuracy= 0.859
# step 5000, Accuracy= 0.875
# step 6000, Accuracy= 0.902
# step 7000, Accuracy= 0.871
# step 8000, Accuracy= 0.926
# step 9000, Accuracy= 0.848
# step 10000, Accuracy= 0.883
# step 11000, Accuracy= 0.891
# step 12000, Accuracy= 0.852
# step 13000, Accuracy= 0.883
# step 14000, Accuracy= 0.867
# step 15000, Accuracy= 0.859
# step 16000, Accuracy= 0.898
# step 17000, Accuracy= 0.887
# step 18000, Accuracy= 0.895
# step 19000, Accuracy= 0.895
# num_iter:20000, lr:0.0001, batch_size:256, n_hidden_1:512, n_hidden_2:256, test_acc:0.8895

# %%
# hyperparameters
NUM_ITER = 20000
lr = 0.001
batch_size = 256
num_input = 784
n_hidden_1 = 512
n_hidden_2 = 256
num_classes = 10

# define variables, weights and biases
tf.reset_default_graph()
X = tf.placeholder(tf.float32,[None, num_input], name='X')
Y = tf.placeholder(tf.int32,[None, num_classes], name='Y')
weights = {
    'W1': tf.Variable(tf.random_normal([num_input, n_hidden_1]), name='W1'),
    'W2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2]), name='W2'),
    'Wout': tf.Variable(tf.random_normal([n_hidden_2, num_classes]), name='Wout')
}
biases = {
    'b1': tf.Variable(tf.zeros(shape=[n_hidden_1]), name='b1'),
    'b2': tf.Variable(tf.zeros(shape=[n_hidden_2]), name='b2'),
    'bout': tf.Variable(tf.zeros(shape=[num_classes]), name='bout')
}
# define neural nets
def neural_net(x):
    x = tf.layers.batch_normalization(x)
    l1_out = tf.nn.relu(tf.add(tf.matmul(x,weights['W1']), biases['b1']))
    l1_out_drop = tf.layers.dropout(l1_out, rate=0.5)
    l2_out = tf.nn.relu(tf.add(tf.matmul(l1_out_drop,weights['W2']), biases['b2']))
    l2_out_drop = tf.layers.dropout(l2_out, rate=0.5)
    out = tf.add(tf.matmul(l2_out_drop, weights['Wout']), biases['bout'])
    return out

logits = neural_net(X)

# define loss and optimizer
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=Y)) #\
     #  + 0.1*(tf.reduce_sum(tf.square(biases['b1'])) + tf.reduce_sum(tf.square(biases['b2'])))
optimizer = tf.train.AdamOptimizer(learning_rate=lr)
train_op = optimizer.minimize(loss)

# evaluate
correct_pred = tf.equal(tf.argmax(logits,1), tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# initialize the variables
init = tf.global_variables_initializer()

# execute training
with tf.Session() as sess:
    sess.run(init)

    for i in range(NUM_ITER):
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        sess.run(train_op, feed_dict={X:batch_x, Y:batch_y})
        if i % 1000 ==0:
             acc = sess.run(accuracy,feed_dict={X:batch_x, Y:batch_y})
             print("step "+str(i)+", Accuracy= {:.3f}".format(acc))

    print("num_iter:%d, lr:%s, batch_size:%d, n_hidden_1:%d, n_hidden_2:%d, test_acc:%.4f" \
          % (NUM_ITER, lr, batch_size, n_hidden_1, n_hidden_2, 
             sess.run(accuracy, feed_dict={X:mnist.test.images, Y:mnist.test.labels})))
# Out:
# step 0, Accuracy= 0.082
# step 1000, Accuracy= 0.898
# step 2000, Accuracy= 0.949
# step 3000, Accuracy= 0.992
# step 4000, Accuracy= 1.000
# step 5000, Accuracy= 0.996
# step 6000, Accuracy= 1.000
# step 7000, Accuracy= 1.000
# step 8000, Accuracy= 0.996
# step 9000, Accuracy= 1.000
# step 10000, Accuracy= 1.000
# step 11000, Accuracy= 1.000
# step 12000, Accuracy= 0.996
# step 13000, Accuracy= 0.996
# step 14000, Accuracy= 1.000
# step 15000, Accuracy= 1.000
# step 16000, Accuracy= 1.000
# step 17000, Accuracy= 1.000
# step 18000, Accuracy= 1.000
# step 19000, Accuracy= 1.000
# num_iter:20000, lr:0.001, batch_size:256, n_hidden_1:512, n_hidden_2:256, test_acc:0.9687

# %%
# hyperparameters
NUM_ITER = 20000
lr = 0.001
batch_size = 256
num_input = 784
n_hidden_1 = 512
n_hidden_2 = 256
num_classes = 10

# define variables, weights and biases
tf.reset_default_graph()
X = tf.placeholder(tf.float32,[None, num_input], name='X')
Y = tf.placeholder(tf.int32,[None, num_classes], name='Y')
weights = {
    'W1': tf.Variable(tf.random_normal([num_input, n_hidden_1]), name='W1'),
    'W2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2]), name='W2'),
    'Wout': tf.Variable(tf.random_normal([n_hidden_2, num_classes]), name='Wout')
}
biases = {
    'b1': tf.Variable(tf.zeros(shape=[n_hidden_1]), name='b1'),
    'b2': tf.Variable(tf.zeros(shape=[n_hidden_2]), name='b2'),
    'bout': tf.Variable(tf.zeros(shape=[num_classes]), name='bout')
}
keep_prob = tf.placeholder(tf.float32)

# define neural nets
def neural_net(x):
    x = tf.layers.batch_normalization(x)
    l1_out = tf.nn.relu(tf.add(tf.matmul(x,weights['W1']), biases['b1']))
    l1_out_drop = tf.layers.dropout(l1_out, rate=keep_prob)
    l2_out = tf.nn.relu(tf.add(tf.matmul(l1_out_drop,weights['W2']), biases['b2']))
    l2_out_drop = tf.layers.dropout(l2_out, rate=keep_prob)
    out = tf.add(tf.matmul(l2_out_drop, weights['Wout']), biases['bout'])
    return out

logits = neural_net(X)

# define loss and optimizer
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=Y)) \
       + 0.1*(tf.reduce_sum(tf.square(biases['b1'])) + tf.reduce_sum(tf.square(biases['b2'])))
learning_rate = tf.train.exponential_decay(lr, 0, 5, 0.85, staircase=True)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss)

# evaluate
correct_pred = tf.equal(tf.argmax(logits,1), tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# initialize the variables
init = tf.global_variables_initializer()

# execute training
with tf.Session() as sess:
    sess.run(init)

    for i in range(NUM_ITER):
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        _, l = sess.run([train_op, loss], feed_dict={X:batch_x, Y:batch_y})
        if i % 1000 ==0:
            acc = sess.run(accuracy,feed_dict={X:batch_x, Y:batch_y, keep_prob:1})
            print("step %d: loss=%.6f, accuracy=%.4f" % (i, l, acc))

    print("num_iter:%d, lr:%s, batch_size:%d, n_hidden_1:%d, n_hidden_2:%d, test_acc:%.4f" \
          % (NUM_ITER, lr, batch_size, n_hidden_1, n_hidden_2, 
             sess.run(accuracy, feed_dict={X:mnist.test.images, Y:mnist.test.labels, keep_prob:1})))
# Out:
# step 0: loss=2784.601807, accuracy=0.0938
# step 1000: loss=32.186310, accuracy=0.9219
# step 2000: loss=2.914062, accuracy=0.9766
# step 3000: loss=0.625857, accuracy=0.9922
# step 4000: loss=1.170040, accuracy=0.9922
# step 5000: loss=0.014707, accuracy=1.0000
# step 6000: loss=0.329930, accuracy=1.0000
# step 7000: loss=0.350679, accuracy=0.9961
# step 8000: loss=0.000964, accuracy=1.0000
# step 9000: loss=0.244540, accuracy=1.0000
# step 10000: loss=0.464424, accuracy=0.9961
# step 11000: loss=0.591554, accuracy=1.0000
# step 12000: loss=0.001446, accuracy=1.0000
# step 13000: loss=0.696095, accuracy=0.9961
# step 14000: loss=0.001632, accuracy=1.0000
# step 15000: loss=0.939032, accuracy=0.9961
# step 16000: loss=0.064610, accuracy=1.0000
# step 17000: loss=0.182159, accuracy=1.0000
# step 18000: loss=0.001163, accuracy=1.0000
# step 19000: loss=0.191521, accuracy=1.0000
# num_iter:20000, lr:0.001, batch_size:256, n_hidden_1:512, n_hidden_2:256, test_acc:0.9675

# %% [markdown]
# <h2>Your results</h2>
